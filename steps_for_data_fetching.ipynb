# %% [markdown]
# ## 🎵 Top Artist Song Lyrics Dataset (2017–2024) — Educational Use Only
#
# This notebook collects and compiles a rich dataset of song lyrics by globally recognized artists from **2017 to 2024**, using publicly available data from music sources.
#
# It includes:
# - Artist names and song titles (fetched from AZLyrics)
# - Corresponding song lyrics (fetched via AZLyrics and Genius where needed)
#
# ⚠️ **Disclaimer:** This dataset is intended strictly for **educational and non-commercial research**. All lyrics remain the intellectual property of their respective rights holders.

# %% [markdown]
# ## 🧭 Notebook Structure & Steps
#
# This notebook follows a step-by-step process to collect and organize song lyrics data from top artists between **2017 and 2024** using publicly available online sources.
#
# ---
#
# ### 🔹 Step 1: Import Required Libraries
# Load all necessary Python libraries including:
# - `requests`, `BeautifulSoup` (for scraping)
# - `pandas`, `time`, `re`, etc.
#
# ---
#
# ### 🔹 Step 2: Scrape Artist Names & Song List Links
# - Loop through the alphabet (A–Z) to fetch artist pages
# - Extract artist names and corresponding song list URLs
# - Save as `azlyrics_artists_links.csv`
#
# ---
#
# ### 🔹 Step 3: Load Top Artist List (2010–2024)
# - Load a CSV file (`top_artist.csv`) containing the most popular global artists
# - Clean artist names for matching
#
# ---
#
# ### 🔹 Step 4: Match Top Artists with AZLyrics Artist List
# - Filter the artists from AZLyrics to include only the top artists from 2017–2024
# - Save final matched artists and their song page links as `filtered_artist_links.csv`
#
# ---
#
# ### 🔹 Step 5: Scrape Each Artist's Songs and Links
# - For each matched artist, extract all songs listed on their page
# - Also collect song URLs and album/year information
# - Save output as `song_links_&_name.csv`
#
# ---
#
# ### 🔹 Step 6: Fetch Song Lyrics (AZLyrics or Genius)
# - Using the song links, fetch lyrics directly
# - If AZLyrics blocks access, fallback to using **Genius search** or **Genius API**
# - Apply text cleaning for NLP-friendly formatting
# - Save full lyrics data as `final_lyrics_dataset.csv`
#
# ---
#
# ### 🔹 Step 7: (Optional) Genius API Usage
# - If enabled, fetch lyrics using the official Genius API with your API key
# - Use only when AZLyrics scraping fails
# - Add results to your final dataset
#
# ---
#
# ### 🔹 Step 8: Final Dataset Overview
# - Load and inspect the final dataset
# - Columns: `artist`, `songs`, `lyrics`
# - Explore sample rows and text length
#
# ---
#
# ### 🔹 Step 9: Save & Upload
# - Save all outputs in CSV format
# - Upload to Kaggle with full documentation, license, and educational disclaimer
#
# ---
#
# 📌 **Note:**
# All lyrics are the property of their respective copyright holders.
# This project is strictly intended for **research and educational purposes only.**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import lyricsgenius

# %% [markdown]
# ## 🔍 Scraping Strategy
#
# 1. Loop through all alphabet letters (`a` to `z`) which represent artist categories on AZLyrics.
# 2. For each letter:
#    - Visit the corresponding URL (e.g., `https://www.azlyrics.com/a.html`).
#    - Parse the artist names and the links to their song list pages.
# 3. Save all artist names and URLs for later use.

# %%
# Letters to iterate over (each represents a separate artist listing page)
letters = list("abcdefghijklmnopqrstuvwxyz")

# Store data
all_artists = []
all_links = []

# Loop through each letter and scrape artist names and their song list links
for letter in letters:
    time.sleep(5.5)  # Be respectful to AZLyrics servers
    url = f"https://www.azlyrics.com/{letter}.html"
    print(f"Fetching: {url}")
    
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all <a> tags and filter only relevant ones
    links = soup.find_all("a")[28:-8]  # Skip unrelated links (based on inspection)
    artist_names = [link.text for link in links]
    artist_urls = [link.get("href") for link in links]

    print(f"Found {len(artist_names)} artists for '{letter.upper()}'")

    all_artists.extend(artist_names)
    all_links.extend(artist_urls)
# Out:
# Fetching: https://www.azlyrics.com/a.html
# Found 1363 artists for 'A'

# %%
all_links
# Out:
# ['a/a1.html',
#  'f/floyda1bentley.html',
#  'a/a1xj1.html',
#  'a/a.html',
#  'a/a2h.html',
#  'a/a36.html',
#  'a/a4.html',
#  'a/a92.html',
#  's/snohaalegra.html',
#  'a/aaliyah.html',
#  's/saaraaalto.html',
#  'a/aaradhna.html',
#  'a/aarne.html',
#  'a/aaroncarpenter.html',
#  'c/carter.html',
#  'a/aaroncole.html',
#  'a/aarondoh.html',
#  'a/aaronfresh.html',
#  'a/aarongoodvin.html',
#  'a/aaronhall.html',
#  'a/aaronlewis.html',
#  'l/lines.html',
#  'a/aaronmay.html',
#  'a/aaronneville.html',
#  'a/aaronpritchett.html',
#  'a/aaronshust.html',
#  'a/aaronsmithuk.html',
#  'a/aaronsmith.html',
#  'a/aarontaos.html',
#  'a/aarontaylor.html',
#  'a/aarontippin.html',
#  'a/aaronwatson.html',
#  'a/aaronwestandtheroaringtwenties.html',
#  'a/aaryanshah.html',
#  'a/aasthagill.html',
#  'a/ab6ix.html',
#  'a/abandonallships.html',
#  'a/abandonedpools.html',
#  'a/abba.html',
#  'a/abbath.html',
#  'a/abbeycone.html',
#  'a/abbeyglover.html',
#  'a/abbiefalls.html',
#  'g/gregoryabbott.html',
#  'a/abbyanderson.html',
#  'a/abbycates.html',
#  'a/abc.html',
#  'a/abdul.html',
#  'a/abelpintos.html',
#  'z/zakabel.html',
#  'a/abeparker.html',
#  'a/abhithenomad.html',
#  'a/abigailbarlow.html',
#  'a/abigailbreslin.html',
#  'h/hevabi.html',
#  'a/abkanybodykilla.html',
#  'a/aborted.html',
#  'a/aboudebeing.html',
#  'a/abovebeyond.html',
#  'a/abovethehood.html',
#  'a/abra.html',
#  'a/abra490149.html',
#  'a/abracadabra.html',
#  'b/benabraham.html',
#  'a/abrahammateo.html',
#  'a/abrahamvazquez.html',
#  'c/caseyabrams.html',
#  'g/gracieabrams.html',
#  'a/abs.html',
#  'a/absentinbody.html',
#  'a/absofacto.html',
#  'a/absoul.html',
#  'a/abstract.html',
#  'k/kevinabstract.html',
#  'a/abu.html',
#  'a/acaciastrain.html',
#  'a/academic.html',
#  'a/academyis.html',
#  'a/accept.html',
#  'a/acceptance.html',
#  'a/accvsed.html',
#  'a/acdc.html',
#  'a/ave-kr.html',
#  'a/ace.html',
#  'a/acebanzuelo.html',
#  'a/acefamily.html',
#  'a/acefrehley.html',
#  'a/acehood.html',
#  'a/aceofbase.html',
#  'a/aces.html',
#  'a/achal.html',
#  'a/achillelauro.html',
#  'a/acidbath.html',
#  'a/acidghost.html',
#  't/tayloracorn.html',
#  'a/acraze.html',
#  'a/acres.html',
#  'a/actionaction.html',
#  'a/actionbronson.html',
#  'a/activechild.html',
#  'a/actorobserver.html',
#  'c/colbyacuff.html',
#  'a/adaam.html',
#  'a/adaband.html',
#  'a/adaehi.html',
#  'a/adamant.html',
#  'a/adamcalhoun.html',
#  'a/adamcraig.html',
#  'a/adamdoleac.html',
#  'a/adamfriedman.html',
#  'a/adamgontier.html',
#  'g/gregory.html',
#  'a/adamjensen.html',
#  'a/adamlambert.html',
#  'a/adamlar.html',
#  'a/adamlevine.html',
#  'a/adammelchor.html',
#  'a/adamport.html',
#  'a/adamsaleh.html',
#  'a/adamsanders.html',
#  's/sandler.html',
#  'a/adams.html',
#  'c/chloeadams.html',
#  'j/joeladams.html',
#  'o/oletaadams.html',
#  'p/peterbradleyadams.html',
#  'a/adamsr.html',
#  's/sammyadams.html',
#  's/simonadams.html',
#  'a/adamsy.html',
#  'i/ivyadara.html',
#  'g/gavinadcock.html',
#  'a/addisonrae.html',
#  'a/addisonroad.html',
#  'm/migoadecer.html',
#  'a/adekunlegold.html',
#  'a/adel.html',
#  'a/adele.html',
#  'a/adelecastillon.html',
#  'a/adelen.html',
#  'a/adelinehill.html',
#  'a/adelitasway.html',
#  't/tanneradell.html',
#  'a/adeltawil.html',
#  'a/adema.html',
#  'a/adept.html',
#  'a/adera.html',
#  'j/jordanadetunji.html',
#  'a/adexenau.html',
#  'a/adfsamski.html',
#  'a/adicts.html',
#  'a/adie.html',
#  'h/howard.html',
#  'a/adinfinitum.html',
#  'a/adinowak.html',
#  'a/adityagadhvi.html',
#  't/traceadkins.html',
#  'a/adl.html',
#  'a/adnansami.html',
#  'a/ado.html',
#  'a/adolescents.html',
#  'a/adonis.html',
#  'a/adora.html',
#  'a/adore.html',
#  'a/adoredelano.html',
#  'c/cemadrian.html',
#  'a/adrianmarcel.html',
#  'a/adriannelenker.html',
#  'a/adrianocelentano.html',
#  'a/adrielfavela.html',
#  'a/adriennebailon.html',
#  'a/adriennunez.html',
#  'a/adultmom.html',
#  'a/adventureclub.html',
#  'a/adysuleiman.html',
#  'a/aegis.html',
#  'a/aer.html',
#  'a/aerisroves.html',
#  'a/aerosmith.html',
#  'a/aerozen.html',
#  'a/aesoprock.html',
#  'a/aespa.html',
#  'a/afgan.html',
#  'a/afghanwhigs.html',
#  'a/afi.html',
#  'a/afrob.html',
#  'a/afrojack.html',
#  'a/afroman.html',
#  'a/after7.html',
#  'a/afterforever.html',
#  'a/afterimage.html',
#  'a/afterlife.html',
#  'a/afterlove.html',
#  'a/afters.html',
#  'a/aftertheburial.html',
#  'a/againstallauthority.html',
#  'a/againstme.html',
#  'a/againstthecurrent.html',
#  'a/agalloch.html',
#  'a/agaragar.html',
#  'a/agathodaimon.html',
#  'a/agclub.html',
#  'a/agentorange.html',
#  'a/ageofinformation.html',
#  'a/aggrosantos.html',
#  'a/agnes.html',
#  'a/agnesmonica.html',
#  'a/agnesobel.html',
#  'f/faltskog.html',
#  't/toddagnew.html',
#  'a/agnosticfront.html',
#  'a/agonist.html',
#  'a/agonyscene.html',
#  'a/agroplay.html',
#  'a/agsunta.html',
#  'f/freddieaguilar.html',
#  'p/pepeaguilar.html',
#  'a/aguilera.html',
#  'a/agustd.html',
#  'a/aha.html',
#  'a/ahagazelle.html',
#  'a/ahi.html',
#  'a/ahmetkaya.html',
#  'p/priscillaahn.html',
#  'a/ahsenalmaz.html',
#  'a/aidanbissett.html',
#  'a/aidanmartin.html',
#  'a/aiden.html',
#  'a/aidengrimshaw.html',
#  'a/aidonia.html',
#  'a/aigel.html',
#  'a/aiken.html',
#  'a/aikko.html',
#  'j/jhene.html',
#  'a/ailee.html',
#  'a/aimantino.html',
#  'a/aimeecarty.html',
#  'a/aimeemann.html',
#  'a/aimer.html',
#  'a/aimyon.html',
#  'a/air.html',
#  'a/airbag.html',
#  'a/airbornetoxicevent.html',
#  'a/airbourne.html',
#  'a/airsupply.html',
#  'a/airtrafficcontroller.html',
#  'a/airways.html',
#  'a/aishabadru.html',
#  'a/aitana.html',
#  'a/aitch.html',
#  'a/aizaseguerra.html',
#  'a/aja.html',
#  'a/ajmclean.html',
#  'a/ajmichalka.html',
#  'a/aj.html',
#  'a/ajr.html',
#  'a/ajrafael.html',
#  'n/nancyajram.html',
#  'a/ajtracey.html',
#  'a/ajxdeno.html',
#  'a/ak420.html',
#  'a/ak47.html',
#  'a/aka.html',
#  'd/demetakaln.html',
#  'a/akausserkontrolle.html',
#  'a/akcent.html',
#  'a/akdongmusicianakmu.html',
#  'a/akia.html',
#  'r/rhettakins.html',
#  'a/akinyele.html',
#  'a/akmal.html',
#  'a/akon.html',
#  'c/christianakridge.html',
#  's/sezenaksu.html',
#  'a/ak.html',
#  'a/alabama.html',
#  'a/alabama3.html',
#  'a/alabamashakes.html',
#  'a/alacranesmusical.html',
#  'y/yemialade.html',
#  'a/aladin135.html',
#  'a/alainacastillo.html',
#  'l/laurenalaina.html',
#  'a/alainsouchon.html',
#  'a/alamid.html',
#  'a/alan.html',
#  'a/alanalee.html',
#  'a/alanaspringsteen.html',
#  'c/cooperalan.html',
#  'a/alani.html',
#  'm/morissette.html',
#  'j/jacksonal.html',
#  'a/alannahmyles.html',
#  'a/alanparsonsproject.html',
#  'a/alanwalker.html',
#  'a/alaskathunderfuck.html',
#  'a/alayna.html',
#  'a/alazka.html',
#  'a/albanorominapower.html',
#  'a/albareche.html',
#  'd/damonalbarn.html',
#  'a/albatraoz.html',
#  'a/albertcollins.html',
#  'a/alberthammond.html',
#  'a/alberthammondjr.html',
#  'a/albertking.html',
#  'a/alberto.html',
#  'z/ziggyalberts.html',
#  'a/albinleemeldau.html',
#  'a/alblak52.html',
#  'p/pabloalboran.html',
#  'a/alborosie.html',
#  'a/albsure.html',
#  'o/ogiealcasid.html',
#  'a/alcatrazz.html',
#  'a/alcazar.html',
#  'a/alcest.html',
#  'a/alchemist.html',
#  'a/alcy.html',
#  'a/aldairplayboy.html',
#  'j/jasonaldean.html',
#  'a/aldenrichards.html',
#  'a/aldn.html',
#  'a/aldonova.html',
#  'a/aldousharding.html',
#  'a/alecbenjamin.html',
#  'a/alecchambers.html',
#  'a/aleemrk.html',
#  'a/aleesia.html',
#  'a/alejandraguzman.html',
#  'a/alejandrofernandez.html',
#  'a/alejandrosanz.html',
#  'a/aleksandraprijovic.html',
#  'a/alekseev.html',
#  'a/aleladiane.html',
#  'a/aleman.html',
#  'a/alesana.html',
#  'a/aleshadixon.html',
#  'a/aleshen.html',
#  'a/alessandra.html',
#  'a/alessiacara.html',
#  'a/alesso.html',
#  'a/alestorm.html',
#  'a/alexa.html',
#  'a/alexacappelli.html',
#  'a/alexademie.html',
#  'a/alexagoddard.html',
#  'a/alexailacad.html',
#  'a/alexaiono.html',
#  'a/alexander23.html',
#  'd/deanalexander.html',
#  'a/alexanderdiaz.html',
#  'a/alexanderjean.html',
#  'k/kitaalexander.html',
#  'a/alexanderludwig.html',
#  'a/alexanderoneal.html',
#  'a/alexanderoscar.html',
#  'r/romanalexander.html',
#  'a/alexanderrybak.html',
#  'a/alexanderstewart.html',
#  'a/alexandraburke.html',
#  'a/alexandrakay.html',
#  'a/alexandrasavior.html',
#  'a/alexandrastan.html',
#  'a/alexavega.html',
#  'a/alexband.html',
#  'a/alexcameron.html',
#  'a/alexcampos.html',
#  'a/alexceesay.html',
#  'a/alexclare.html',
#  'a/alexdakid.html',
#  'a/alexday.html',
#  'a/alexfavela.html',
#  'a/alexg.html',
#  'a/alexgaudino.html',
#  'a/alexgonzaga.html',
#  'a/alexgoot.html',
#  'a/alexhepburn.html',
#  'a/alexiane.html',
#  'a/aleximurdoch.html',
#  'a/alexisjordan.html',
#  'a/alexisley.html',
#  'a/alexismunroe.html',
#  'a/alexisonfire.html',
#  'a/alexisfido.html',
#  'a/alexjarvi.html',
#  'a/alexjean.html',
#  'a/alexlahey.html',
#  'a/alexlora.html',
#  'a/alexmali.html',
#  'a/alexmattson.html',
#  'a/alexmica.html',
#  'a/alexnewell.html',
#  'a/alexparks.html',
#  'a/alexporat.html',
#  'a/alexrose.html',
#  'a/alexsampson.html',
#  'a/alexsensation.html',
#  'a/alexsierra.html',
#  'a/alextbh.html',
#  'a/alexturner.html',
#  'a/alexubago.html',
#  'a/alexvargas.html',
#  'a/alexvaughn.html',
#  'a/alexwarren.html',
#  'a/alexwiley.html',
#  'a/alexxcalise.html',
#  'a/alexzjohnson.html',
#  'a/aleyna.html',
#  'a/aleynatilki.html',
#  'a/alfa.html',
#  'a/alffyrev.html',
#  'a/alfiecastley.html',
#  'a/alfietempleman.html',
#  'a/alfiezumi.html',
#  'a/alfredoolivas.html',
#  'a/algiers.html',
#  'a/algreen.html',
#  'a/ali471.html',
#  'a/alias.html',
#  'a/ali-as.html',
#  'a/alib.html',
#  'a/alicechater.html',
#  'a/alicecooper.html',
#  'a/aliceglass.html',
#  'a/aliceinchains.html',
#  'a/alicekristiansen.html',
#  'a/alicemerton.html',
#  'a/alicepeacock.html',
#  'a/alicephoebelou.html',
#  'a/aliciabridges.html',
#  'a/aliciakeys.html',
#  'a/aliciamoffet.html',
#  'a/alienantfarm.html',
#  'a/alienweaponry.html',
#  'a/alig.html',
#  'a/aligatie.html',
#  'a/alika.html',
#  'a/alilohan.html',
#  'm/maejorali.html',
#  'a/alina.html',
#  'a/alinabaraz.html',
#  'n/nadiaali.html',
#  'a/alinebarros.html',
#  'a/aliochaschneider.html',
#  'a/aliottahaynesjeremiah.html',
#  'a/alisaturner.html',
#  'a/alishasattic.html',
#  'a/alisongold.html',
#  'k/krauss.html',
#  'a/alisonmoyet.html',
#  'a/alisonwonderland.html',
#  'a/alissic.html',
#  'a/alissonshore.html',
#  'a/alivelikeme.html',
#  'a/aliyahsinterlude.html',
#  'a/alizade.html',
#  'a/alizee.html',
#  'a/aljames.html',
#  'a/aljarreau.html',
#  'a/alkaline.html',
#  'a/alkalinetrio.html',
#  'h/humoodalkhudher.html',
#  'a/alkilados.html',
#  'a/alkpote.html',
#  'a/all.html',
#  'a/all4one.html',
#  'a/allaboutshe.html',
#  'a/allahlas.html',
#  'a/allame.html',
#  'a/allamericanrejects.html',
#  'g/garyallan.html',
#  'a/allanrayman.html',
#  'a/allblack.html',
#  'a/allbut6.html',
#  'a/allday.html',
#  'a/allefarben.html',
#  'a/allegaeon.html',
#  'a/allele.html',
#  'h/hoodieallen.html',
#  'j/jimmieallen.html',
#  'k/krisallen.html',
#  'a/allenlande.html',
#  'l/lilyallen.html',
#  'p/peterallen.html',
#  'a/allenstone.html',
#  'a/alleviate.html',
#  'c/candice.html',
#  'a/allformetal.html',
#  'a/allgetout.html',
#  'a/allgoodthings.html',
#  'a/allhours.html',
#  'a/alliex.html',
#  'a/alligatoah.html',
#  'a/allisimpson.html',
#  'a/allisoniraheta.html',
#  'a/allisonponthier.html',
#  'a/allisonrussell.html',
#  'a/allister.html',
#  'a/allj.html',
#  'a/allmanbrothersband.html',
#  'a/allmanbrown.html',
#  'g/greggallman.html',
#  'a/allmot.html',
#  'a/allsaints.html',
#  'a/allshallperish.html',
#  'a/allsonsdaughters.html',
#  'a/allstartribute.html',
#  'a/allstarweekend.html',
#  'a/allt.html',
#  'a/allthatremains.html',
#  'a/allthemwitches.html',
#  'a/alltimelow.html',
#  'a/allure.html',
#  'a/alluvial.html',
#  'a/allweare.html',
#  'a/allybrooke.html',
#  'a/allyburnett.html',
#  'a/allyhills.html',
#  'a/alma.html',
#  'a/alma7758.html',
#  'b/barbiealmalbis.html',
#  'a/almanac.html',
#  'a/almary.html',
#  'a/almighty.html',
#  'm/marcalmond.html',
#  'a/almostfamous.html',
#  'a/almostmonday.html',
#  'a/almost.html',
#  'i/issamalnajjar.html',
#  'a/aloeblacc.html',
#  'a/alok.html',
#  'j/jarrodalonge.html',
#  'a/alonzo.html',
#  'a/alpagun.html',
#  'h/herbalpert.html',
#  'a/alphabeat.html',
#  'a/alpharev.html',
#  'a/alphaville.html',
#  'a/alphawann.html',
#  'a/alphawolf.html',
#  'a/alpine.html',
#  'a/alrima.html',
#  'a/alsou.html',
#  'a/alstewart.html',
#  'a/alt.html',
#  'a/altaconsigna.html',
#  'a/altblkera.html',
#  'a/alterbridge.html',
#  'a/alteredimages.html',
#  'a/altheadonna.html',
#  'a/altiyanchilds.html',
#  'a/altj.html',
#  'a/altons.html',
#  'b/berkayaltunyay.html',
#  'a/aluna.html',
#  'a/alunageorge.html',
#  'a/alvarodeluna.html',
#  'a/alvarodiaz.html',
#  'a/alvarosoler.html',
#  's/sonnyalven.html',
#  'a/alvinandthechipmunks.html',
#  'a/alvinlee.html',
#  't/tiffanyalvord.html',
#  'a/alvvays.html',
#  'a/alwaysnever.html',
#  'a/alwilson.html',
#  'a/alyaj.html',
#  'a/alyonaalyona.html',
#  'a/alyonashvets.html',
#  'a/alysonstoner.html',
#  'a/alyssareid.html',
#  'a/alzx38.html',
#  'a/am.html',
#  'a/amaarae.html',
#  'r/ryanamador.html',
#  'a/amaia.html',
#  'a/amaiaalfred.html',
#  'a/amaiamontero.html',
#  'a/amalee.html',
#  'a/amalou.html',
#  'a/amanda.html',
#  'a/amandablack.html',
#  'a/amandacook.html',
#  'a/amandadelara.html',
#  'a/amandamarshall.html',
#  'a/amandapalmer.html',
#  'p/perez.html',
#  'a/amandaseyfried.html',
#  'a/amandashires.html',
#  'a/amandasomerville.html',
#  'a/amandastott.html',
#  'a/amaral.html',
#  'a/amaralanegra.html',
#  'r/rodrigoamarante.html',
#  'a/amaranthe.html',
#  'm/melanieamaro.html',
#  'b/benjaminamaru.html',
#  'a/amazingdevil.html',
#  'a/amazons.html',
#  'a/ambarlucid.html',
#  'a/amberiandawn.html',
#  'a/ambermark.html',
#  'a/amberpacific.html',
#  'a/amberriley.html',
#  'a/amberrose.html',
#  'a/amberrun.html',
#  'a/ambjaay.html',
#  'a/amble.html',
#  'm/markambor.html',
#  'a/ambrosia.html',
#  'm/marshaambrosius.html',
#  'a/ambushbuzzworl.html',
#  'a/amee.html',
#  'a/ameervann.html',
#  'a/amelbent.html',
#  'a/amelialily.html',
#  'a/ameliamonet.html',
#  'a/ameliamoore.html',
#  'a/amellarrieux.html',
#  'a/amenazzy.html',
#  'a/amendunes.html',
#  'a/amenra.html',
#  'c/chloeament.html',
#  'a/america.html',
#  'a/americanaquarium.html',
#  'a/americanauthors.html',
#  'a/americanfootball.html',
#  'a/americanhead.html',
#  'a/americanhifi.html',
#  'a/americanjuniors.html',
#  'a/americannightmare.html',
#  'a/americanos.html',
#  'a/americanpleasureclub.html',
#  'a/amerie.html',
#  'a/amiciforever.html',
#  'a/amiel.html',
#  'a/amielsol.html',
#  'a/amigdala.html',
#  'a/amigothedevil.html',
#  'a/amiistewart.html',
#  'a/aminabuddafly.html',
#  'a/amine.html',
#  'a/amir.html',
#  'a/amirchik.html',
#  'a/amirobe.html',
#  'a/amistat.html',
#  'a/amityaffliction.html',
#  'n/nadinamizah.html',
#  'a/amlascampia.html',
#  'a/amna.html',
#  'a/amo988.html',
#  'a/amonamarth.html',
#  'v/vanessaamorosi.html',
#  'a/amorphis.html',
#  'a/amorphous.html',
#  'a/amoslee.html',
#  'a/amos.html',
#  'a/ampersone.html',
#  'j/johnamplificado.html',
#  'a/amritmaan.html',
#  'a/amyadams.html',
#  'a/amygrant.html',
#  'a/amylandthesniffers.html',
#  'a/amylee.html',
#  'a/amymacdonald.html',
#  'a/amymeredith.html',
#  'a/amypearson.html',
#  'a/amyshark.html',
#  's/studt.html',
#  'a/amywadge.html',
#  'a/amywinehouse.html',
#  'a/anaalnathrakh.html',
#  'a/anabelenglund.html',
#  'a/anacastela.html',
#  'a/anacondaz.html',
#  'a/anagabriel.html',
#  'a/anagabriela.html',
#  'a/anaguerra.html',
#  'a/anahi.html',
#  'j/johnsson.html',
#  'a/anamanaguchi.html',
#  'a/anamena.html',
#  'a/ananda.html',
#  'a/ananikolic.html',
#  'a/ananyabirla.html',
#  'a/anarbor.html',
#  'a/anastacia.html',
#  'a/anastasiacast.html',
#  'a/anastasija.html',
#  'a/anathema.html',
#  'a/anavitoria.html',
#  'a/anberlin.html',
#  'a/anbu.html',
#  'a/ancientbards.html',
#  'a/anders.html',
#  'a/anderslystell.html',
#  'b/bonnieanderson.html',
#  'b/bowanderson.html',
#  'c/coffeyanderson.html',
#  'a/andersoneast.html',
#  'j/johnanderson.html',
#  'j/jonanderson.html',
#  'k/keithanderson.html',
#  'l/lynnanderson.html',
#  'l/lyricaanderson.html',
#  'a/anderson-paak.html',
#  'a/andi.html',
#  'a/andiecase.html',
#  't/tiaraandini.html',
#  'a/andmesh.html',
#  'b/bobiandonov.html',
#  'a/andra.html',
#  'a/andraandthebackbone.html',
#  'a/andraday.html',
#  'd/danielaandrade.html',
#  'a/andre3000.html',
#  'a/andreabocelli.html',
#  'a/andreabrillantes.html',
#  'a/andreacorr.html',
#  'a/andrearussett.html',
#  'a/andreasbourani.html',
#  'a/andreasodbjerg.html',
#  'a/andreatrueconnection.html',
#  'a/andrenickatina.html',
#  'a/andre.html',
#  'a/andrescalamaro.html',
#  'i/ingridandress.html',
#  'a/andrewallen.html',
#  'a/andrewbelle.html',
#  'a/andrewbird.html',
#  'a/andrewe.html',
#  'a/andrewgarcia.html',
#  'a/andrewgold.html',
#  'a/andrewjacksonjihad.html',
#  'a/andrewjannakos.html',
#  'a/andrewmcmahoninthewilderness.html',
#  'a/andrewpeterson.html',
#  'a/andrewripp.html',
#  'b/bryanandrews.html',
#  'c/courtneymarieandrews.html',
#  'a/andrews.html',
#  'm/meredithandrews.html',
#  'a/andrewwk.html',
#  'd/danandriano.html',
#  'a/andro.html',
#  'a/androids.html',
#  'a/andyblack.html',
#  'a/andybrown.html',
#  'a/andygibb.html',
#  'a/andygrammer.html',
#  'a/andygriggs.html',
#  'a/andykim.html',
#  'a/andymineo.html',
#  'a/andyouwillknowusbythetrailofdead.html',
#  'a/andyrivera.html',
#  'a/andyshauf.html',
#  'a/andywilliams.html',
#  'a/anebrun.html',
#  'a/anees.html',
#  'a/anellaherim.html',
#  'a/anetsai.html',
#  'a/anetteolzon.html',
#  'a/anfarose.html',
#  'a/angelaaguilar.html',
#  'a/angelaammons.html',
#  'a/angelabofill.html',
#  'a/angelaken.html',
#  'a/angel.html',
#  'a/angelawinbush.html',
#  'a/angeldust.html',
#  'a/angle.html',
#  'a/angelhaze.html',
#  'a/angelinajordan.html',
#  'a/angelinamango.html',
#  'a/angelinequinto.html',
#  's/steveangello.html',
#  'a/angelmaker.html',
#  'a/angelodeaugustine.html',
#  'a/angelolsen.html',
#  'a/angelsairwaves.html',
#  'a/angelsfall.html',
#  'a/angel4453.html',
#  'a/angels-usa.html',
#  'a/angels.html',
#  'a/angeltaylor.html',
#  'a/angelusapatrida.html',
#  'a/anggimarito.html',
#  'a/anggun.html',
#  'a/angie.html',
#  'm/martinez.html',
#  'a/angiemcmahon.html',
#  'a/angiemiller.html',
#  's/stonean.html',
#  'a/angra.html',
#  'a/angusjuliastone.html',
#  'a/angusmcsix.html',
#  'a/angusstone.html',
#  'a/angykreyda.html',
#  'a/ani.html',
#  'd/difranco.html',
#  'a/anikv.html',
#  'a/anilorak.html',
#  'a/anilyst.html',
#  'a/animalcollective.html',
#  'a/animals.html',
#  'a/animotion.html',
#  'a/animus.html',
#  'a/anitabaker.html',
#  'a/anitaward.html',
#  'a/anitawilson.html',
#  'a/anitta.html',
#  'a/anivar.html',
#  'a/anlemredaldal.html',
#  'a/anji.html',
#  'a/anjulie.html',
#  'p/paulanka.html',
#  'a/anna.html',
#  'a/annaasti.html',
#  'a/annablue.html',
#  'a/annacalvi.html',
#  'a/annaclendening.html',
#  'a/annagrace.html',
#  'a/annagraceman.html',
#  'a/annahmac.html',
#  'a/annakendrick.html',
#  'a/annaleone.html',
#  'a/annalisa.html',
#  'a/annamargaret.html',
#  'a/annanaklab.html',
#  'a/annanalick.html',
#  'a/annaofthenorth.html',
#  'a/annatrincher.html',
#  'a/annawise.html',
#  'a/annehathaway.html',
#  'a/annekevangiersbergen.html',
#  'a/anneliesevanderpol.html',
#  'a/annemarie.html',
#  'a/annemurray.html',
#  'a/annenmaykantereit.html',
#  'a/anneth.html',
#  'a/annewilson.html',
#  'a/anniedirusso.html',
#  'a/annieleblanc.html',
#  'l/lennox.html',
#  'a/annihilator.html',
#  'a/annikarose.html',
#  'a/anninblack.html',
#  'a/annisokay.html',
#  'a/annmarie.html',
#  'a/annmarr.html',
#  'a/annpeebles.html',
#  'a/anohni.html',
#  'a/anonym.html',
#  'a/anotherdaydawns.html',
#  'a/anouk.html',
#  'a/ans.html',
#  'a/anselelgort.html',
#  'a/anser.html',
#  'a/ansonseabra.html',
#  'a/answer.html',
#  'a/antagonizer.html',
#  'a/antbeale.html',
#  'a/antclemons.html',
#  'a/anth.html',
#  'a/anthemlights.html',
#  'a/anthonyamorim.html',
#  'a/anthonybrown.html',
#  'a/anthonycallea.html',
#  'a/anthonydavid.html',
#  'a/anthonyevans.html',
#  'a/anthonygreen.html',
#  'h/hamilton.html',
#  'a/anthonylewis.html',
#  'a/anthony.html',
#  'o/oliveranthony.html',
#  'a/anthonyramos.html',
#  'a/anthonyrusso.html',
#  's/sethanthony.html',
#  'a/anthrax.html',
#  'a/antiflag.html',
#  'a/antilopengang.html',
#  'a/antimatter.html',
#  'a/antlers.html',
#  'a/antoinedodson.html',
#  'm/maggieantone.html',
#  'a/antonia.html',
#  'a/antonioaguilar.html',
#  'a/antoniojose.html',
#  'a/antonyandthejohnsons.html',
#  'a/antoon.html',
#  'a/antsaunders.html',
#  'a/antslive.html',
#  'a/antwan.html',
#  'a/antytila.html',
#  'a/anuelaa.html',
#  'a/anuhea.html',
#  'a/anuvjain.html',
#  'a/anvil.html',
#  'a/anxious.html',
#  'a/anya.html',
#  'a/anyamarina.html',
#  'a/anycia.html',
#  'a/anygivenday.html',
#  'a/anygivensin.html',
#  'a/anyma.html',
#  'a/anywaygang.html',
#  'a/aoa.html',
#  'a/aoen.html',
#  'a/aoifeodonovan.html',
#  's/steveaoki.html',
#  'a/apache207.html',
#  'a/apartment26.html',
#  'a/apashe.html',
#  'a/apdhillon.html',
#  'k/keithape.html',
#  'a/apekz.html',
#  'a/apextheory.html',
#  'a/apfs.html',
#  'a/aphroditeschild.html',
#  'a/apink.html',
#  'g/gabrielleaplin.html',
#  'a/apocalyptica.html',
#  'a/apohikingsociety.html',
#  'a/apolloltd.html',
#  'n/naethanapollo.html',
#  'o/omarapollo.html',
#  'a/apon.html',
#  'a/apored.html',
#  'a/apparat.html',
#  'a/apple.html',
#  'j/johnnyapple.html',
#  'a/applesinstereo.html',
#  's/stevieappleton.html',
#  'a/april.html',
#  'a/aprilboys.html',
#  'a/aprilsmith.html',
#  'a/aprilsmithandthegreatpictureshow.html',
#  'a/aprilwine.html',
#  'a/apent.html',
#  'a/aqua.html',
#  'a/aqualung.html',
#  'l/laurenaquilina.html',
#  'a/aquilo.html',
#  'a/aqyila.html',
#  'a/aranda.html',
#  'f/fundaarar.html',
#  'a/arash.html',
#  'a/arashbuana.html',
#  'a/arashi.html',
#  'c/cristianoaraujo.html',
#  'a/arca.html',
#  'a/arcadefire.html',
#  'a/arcadia.html',
#  'a/arcadian.html',
#  'a/arcadianwild.html',
#  'a/arcaneroots.html',
#  'a/arcangel.html',
#  'a/arcangels.html',
#  'a/archenemy.html',
#  'a/archers.html',
#  't/tasminarcher.html',
#  'a/archetypescollide.html',
#  'a/archiebellthedrells.html',
#  'a/archies.html',
#  'a/architects.html',
#  'a/architectureinhelsinki.html',
#  'a/archive.html',
#  'a/archspire.html',
#  'd/davidarchuleta.html',
#  'a/arcnorth.html',
#  'a/arcs.html',
#  'a/arcticmonkeys.html',
#  'a/arcturus.html',
#  'a/ardadz.html',
#  'a/ardagezer.html',
#  'j/jannarden.html',
#  'a/ardenjones.html',
#  'a/ardhitopramono.html',
#  'a/ardianbujupi.html',
#  'a/area11.html',
#  'a/area21.html',
#  'a/areece.html',
#  'a/arena.html',
#  'a/arethafranklin.html',
#  'a/argent.html',
#  'a/ariabdul.html',
#  'a/arianadebose.html',
#  'a/arianagrande.html',
#  'p/putriariani.html',
#  'a/aribeatz.html',
#  'a/arielcamacho.html',
#  'a/arielpink.html',
#  'a/arielrivera.html',
#  'a/aries.html',
#  'a/ariete.html',
#  'a/arif.html',
#  'a/arihest.html',
#  'a/arijitsingh.html',
#  'a/arikakane.html',
#  ...]

# %% [markdown]
# ## 📁 Combine and Save Data
#
# We now save the artist names and their respective song page URLs into a structured DataFrame and export it as a CSV file for future use.

# %%
# Create full URLs from relative paths (AZLyrics uses relative links)
base_url = "https://www.azlyrics.com/"

# Convert relative links to full URLs
full_links = [link if link.startswith("http") else base_url + link.lstrip("../") for link in all_links]

# Create a DataFrame
df = pd.DataFrame({
    "artist": all_artists,
    "link": full_links
})

# Preview
df.head()
# Out:
#     artist                                            link
# 0       a1              https://www.azlyrics.com/a/a1.html
# 1       A1  https://www.azlyrics.com/f/floyda1bentley.html
# 2  A1 x J1           https://www.azlyrics.com/a/a1xj1.html
# 3        A               https://www.azlyrics.com/a/a.html
# 4      A2H             https://www.azlyrics.com/a/a2h.html

# %%
df.to_csv("azlyrics_artists_links.csv", index=False)

# %% [markdown]
# ## 🎯 Filter Top Artists from Full AZLyrics Dataset
#
# Now that we have saved the complete list of all artists and their AZLyrics links to `azlyrics_artists_links.csv`, we will:
#
# 1. Load our list of **Top Artists** (e.g., downloaded from Kaggle or another source).
# 2. Match them against the AZLyrics artist names.
# 3. Filter and extract only the matching artists along with their lyrics page links.
# 4. Save this filtered list to a new file: `filtered_artist_links.csv`.

# %%
import pandas as pd

# Load full artist dataset with links from AZLyrics
dff = pd.read_csv("azlyrics_artists_links.csv")  # Columns: artist, link

# Load top artists list (downloaded separately)
data1 = pd.read_csv("top_artist.csv")  # Column: artist

# Create a DataFrame to hold matching artist-link pairs
filtered_df = pd.DataFrame(columns=["artist", "link"])

# Match top artists with AZLyrics artists
for i in range(len(data1)):
    top_artist = str(data1["artist"][i]).lower().replace(" ", "").strip()

    for j in range(len(dff)):
        az_artist = str(dff["artist"][j]).lower().replace(" ", "").strip()

        if top_artist == az_artist:
            print(f"✅ MATCH: {top_artist} == {az_artist}")
            filtered_df.loc[len(filtered_df)] = [dff["artist"][j], dff["link"][j]]

# Drop duplicates
filtered_df = filtered_df.drop_duplicates()

# Save to new CSV
# Out:
# ✅ MATCH: kesha == kesha
# ✅ MATCH: rihanna == rihanna
# ✅ MATCH: ladygaga == ladygaga
# ✅ MATCH: jasonderulo == jasonderulo
# ✅ MATCH: katyperry == katyperry
# ✅ MATCH: brunomars == brunomars
# ✅ MATCH: taiocruz == taiocruz
# ✅ MATCH: blackeyedpeas == blackeyedpeas
# ✅ MATCH: usher == usher
# ✅ MATCH: taylorswift == taylorswift
# ✅ MATCH: b.o.b == b.o.b
# ✅ MATCH: eminem == eminem
# ✅ MATCH: train == train
# ✅ MATCH: mikeposner == mikeposner
# ✅ MATCH: drake == drake
# ✅ MATCH: onerepublic == onerepublic
# ✅ MATCH: justinbieber == justinbieber
# ✅ MATCH: nickiminaj == nickiminaj
# ✅ MATCH: adamlambert == adamlambert
# ✅ MATCH: ludacris == ludacris
# ✅ MATCH: davidguetta == davidguetta
# ✅ MATCH: ladyantebellum == ladyantebellum
# ✅ MATCH: jay-z == jay-z
# ✅ MATCH: pitbull == pitbull
# ✅ MATCH: iyaz == iyaz
# ✅ MATCH: timbaland == timbaland
# ✅ MATCH: nelly == nelly
# ✅ MATCH: laroux == laroux
# ✅ MATCH: daughtry == daughtry
# ✅ MATCH: shontelle == shontelle
# ✅ MATCH: jaysean == jaysean
# ✅ MATCH: fareastmovement == fareastmovement
# ✅ MATCH: selenagomez&thescene == selenagomez&thescene
# ✅ MATCH: traviemccoy == traviemccoy
# ✅ MATCH: johnmayer == johnmayer
# ✅ MATCH: enriqueiglesias == enriqueiglesias
# ✅ MATCH: orianthi == orianthi
# ✅ MATCH: neontrees == neontrees
# ✅ MATCH: paramore == paramore
# ✅ MATCH: maroon5 == maroon5
# ✅ MATCH: akon == akon
# ✅ MATCH: treysongz == treysongz
# ✅ MATCH: wethekings == wethekings
# ✅ MATCH: florida == florida
# ✅ MATCH: lilwayne == lilwayne
# ✅ MATCH: nickelback == nickelback
# ✅ MATCH: boyslikegirls == boyslikegirls
# ✅ MATCH: pink == pink
# ✅ MATCH: krisallen == krisallen
# ✅ MATCH: ceelogreen == ceelogreen
# ✅ MATCH: aliciakeys == aliciakeys
# ✅ MATCH: michaelbuble == michaelbuble
# ✅ MATCH: owlcity == owlcity
# ✅ MATCH: will.i.am == will.i.am
# ✅ MATCH: snoopdogg == snoopdogg
# ✅ MATCH: seankingston == seankingston
# ✅ MATCH: youngmoney == youngmoney
# ✅ MATCH: kellyclarkson == kellyclarkson
# ✅ MATCH: auburn == auburn
# ✅ MATCH: mileycyrus == mileycyrus
# ✅ MATCH: sarabareilles == sarabareilles
# ✅ MATCH: lifehouse == lifehouse
# ✅ MATCH: mirandacosgrove == mirandacosgrove
# ✅ MATCH: justintimberlake == justintimberlake
# ✅ MATCH: hayleywilliams == hayleywilliams
# ✅ MATCH: chrisbrown == chrisbrown
# ✅ MATCH: jessemccartney == jessemccartney
# ✅ MATCH: newboyz == newboyz
# ✅ MATCH: t.i. == t.i.
# ✅ MATCH: diddy-dirtymoney == diddy-dirtymoney
# ✅ MATCH: unclekracker == unclekracker
# ✅ MATCH: britneyspears == britneyspears
# ✅ MATCH: robthomas == robthomas
# ✅ MATCH: kevinrudolf == kevinrudolf
# ✅ MATCH: kanyewest == kanyewest
# ✅ MATCH: christinaaguilera == christinaaguilera
# ✅ MATCH: lloyd == lloyd
# ✅ MATCH: edwardmaya == edwardmaya
# ✅ MATCH: ne-yo == ne-yo
# ✅ MATCH: cascada == cascada
# ✅ MATCH: hotchellerae == hotchellerae
# ✅ MATCH: willow == willow
# ✅ MATCH: theoryofadeadman == theoryofadeadman
# ✅ MATCH: goodcharlotte == goodcharlotte
# ✅ MATCH: shinedown == shinedown
# ✅ MATCH: sickpuppies == sickpuppies
# ✅ MATCH: fabolous == fabolous
# ✅ MATCH: sugarland == sugarland
# ✅ MATCH: liljon == liljon
# ✅ MATCH: seanpaul == seanpaul
# ✅ MATCH: youngjeezy == youngjeezy
# ✅ MATCH: runnerrunner == runnerrunner
# ✅ MATCH: carrieunderwood == carrieunderwood
# ✅ MATCH: adele == adele
# ✅ MATCH: lmfao == lmfao
# ✅ MATCH: wizkhalifa == wizkhalifa
# ✅ MATCH: avrillavigne == avrillavigne
# ✅ MATCH: dev == dev
# ✅ MATCH: cobrastarship == cobrastarship
# ✅ MATCH: jenniferlopez == jenniferlopez
# ✅ MATCH: lupefiasco == lupefiasco
# ✅ MATCH: gymclassheroes == gymclassheroes
# ✅ MATCH: jessiej == jessiej
# ✅ MATCH: fosterthepeople == fosterthepeople
# ✅ MATCH: t-pain == t-pain
# ✅ MATCH: christinaperri == christinaperri
# ✅ MATCH: tinietempah == tinietempah
# ✅ MATCH: afrojack == afrojack
# ✅ MATCH: badmeetsevil == badmeetsevil
# ✅ MATCH: coldplay == coldplay
# ✅ MATCH: kerihilson == kerihilson
# ✅ MATCH: alexandrastan == alexandrastan
# ✅ MATCH: gavindegraw == gavindegraw
# ✅ MATCH: plainwhitet's == plainwhitet's
# ✅ MATCH: blakeshelton == blakeshelton
# ✅ MATCH: jeremih == jeremih
# ✅ MATCH: andygrammer == andygrammer
# ✅ MATCH: nicolescherzinger == nicolescherzinger
# ✅ MATCH: adamlevine == adamlevine
# ✅ MATCH: linkinpark == linkinpark
# ✅ MATCH: jasonaldean == jasonaldean
# ✅ MATCH: mychemicalromance == mychemicalromance
# ✅ MATCH: bigtimerush == bigtimerush
# ✅ MATCH: wakaflockaflame == wakaflockaflame
# ✅ MATCH: lukebryan == lukebryan
# ✅ MATCH: breathecarolina == breathecarolina
# ✅ MATCH: calvinharris == calvinharris
# ✅ MATCH: j.cole == j.cole
# ✅ MATCH: ericturner == ericturner
# ✅ MATCH: rickross == rickross
# ✅ MATCH: kellyrowland == kellyrowland
# ✅ MATCH: bigsean == bigsean
# ✅ MATCH: zacbrownband == zacbrownband
# ✅ MATCH: dr.dre == dr.dre
# ✅ MATCH: outasight == outasight
# ✅ MATCH: mattnathanson == mattnathanson
# ✅ MATCH: djkhaled == djkhaled
# ✅ MATCH: onedirection == onedirection
# ✅ MATCH: fun. == fun.
# ✅ MATCH: carlyraejepsen == carlyraejepsen
# ✅ MATCH: elliegoulding == elliegoulding
# ✅ MATCH: demilovato == demilovato
# ✅ MATCH: alexclare == alexclare
# ✅ MATCH: karmin == karmin
# ✅ MATCH: cherlloyd == cherlloyd
# ✅ MATCH: gotye == gotye
# ✅ MATCH: phillipphillips == phillipphillips
# ✅ MATCH: jasonmraz == jasonmraz
# ✅ MATCH: sia == sia
# ✅ MATCH: ritaora == ritaora
# ✅ MATCH: edsheeran == edsheeran
# ✅ MATCH: neonhitch == neonhitch
# ✅ MATCH: havanabrown == havanabrown
# ✅ MATCH: grouplove == grouplove
# ✅ MATCH: kimbra == kimbra
# ✅ MATCH: sammyadams == sammyadams
# ✅ MATCH: k'naan == k'naan
# ✅ MATCH: imaginedragons == imaginedragons
# ✅ MATCH: conormaynard == conormaynard
# ✅ MATCH: tyga == tyga
# ✅ MATCH: ollymurs == ollymurs
# ✅ MATCH: chriswallace == chriswallace
# ✅ MATCH: bridgitmendler == bridgitmendler
# ✅ MATCH: chrisrene == chrisrene
# ✅ MATCH: nodoubt == nodoubt
# ✅ MATCH: jojo == jojo
# ✅ MATCH: colbiecaillat == colbiecaillat
# ✅ MATCH: kirkobangz == kirkobangz
# ✅ MATCH: swedishhousemafia == swedishhousemafia
# ✅ MATCH: madonna == madonna
# ✅ MATCH: megan&liz == megan&liz
# ✅ MATCH: nellyfurtado == nellyfurtado
# ✅ MATCH: littlebigtown == littlebigtown
# ✅ MATCH: hunterhayes == hunterhayes
# ✅ MATCH: selenagomez == selenagomez
# ✅ MATCH: zedd == zedd
# ✅ MATCH: avicii == avicii
# ✅ MATCH: lorde == lorde
# ✅ MATCH: iconapop == iconapop
# ✅ MATCH: falloutboy == falloutboy
# ✅ MATCH: robinthicke == robinthicke
# ✅ MATCH: capitalcities == capitalcities
# ✅ MATCH: floridageorgialine == floridageorgialine
# ✅ MATCH: annakendrick == annakendrick
# ✅ MATCH: daftpunk == daftpunk
# ✅ MATCH: mumford&sons == mumford&sons
# ✅ MATCH: awolnation == awolnation
# ✅ MATCH: ofmonstersandmen == ofmonstersandmen
# ✅ MATCH: arianagrande == arianagrande
# ✅ MATCH: kendricklamar == kendricklamar
# ✅ MATCH: nikkiwilliams == nikkiwilliams
# ✅ MATCH: passenger == passenger
# ✅ MATCH: muse == muse
# ✅ MATCH: miguel == miguel
# ✅ MATCH: emblem3 == emblem3
# ✅ MATCH: lanadelrey == lanadelrey
# ✅ MATCH: austinmahone == austinmahone
# ✅ MATCH: nateruess == nateruess
# ✅ MATCH: mikkyekko == mikkyekko
# ✅ MATCH: bonniemckee == bonniemckee
# ✅ MATCH: littlemix == littlemix
# ✅ MATCH: brittnicole == brittnicole
# ✅ MATCH: fifthharmony == fifthharmony
# ✅ MATCH: mariahcarey == mariahcarey
# ✅ MATCH: labrinth == labrinth
# ✅ MATCH: johnnewman == johnnewman
# ✅ MATCH: zendaya == zendaya
# ✅ MATCH: arminvanbuuren == arminvanbuuren
# ✅ MATCH: macmiller == macmiller
# ✅ MATCH: bastille == bastille
# ✅ MATCH: mirandalambert == mirandalambert
# ✅ MATCH: samsmith == samsmith
# ✅ MATCH: iggyazalea == iggyazalea
# ✅ MATCH: charlixcx == charlixcx
# ✅ MATCH: nico&vinz == nico&vinz
# ✅ MATCH: meghantrainor == meghantrainor
# ✅ MATCH: tovelo == tovelo
# ✅ MATCH: mkto == mkto
# ✅ MATCH: johnlegend == johnlegend
# ✅ MATCH: magic! == magic!
# ✅ MATCH: rixton == rixton
# ✅ MATCH: americanauthors == americanauthors
# ✅ MATCH: disclosure == disclosure
# ✅ MATCH: echosmith == echosmith
# ✅ MATCH: mr.probz == mr.probz
# ✅ MATCH: nickjonas == nickjonas
# ✅ MATCH: aloeblacc == aloeblacc
# ✅ MATCH: martingarrix == martingarrix
# ✅ MATCH: shakira == shakira
# ✅ MATCH: kongos == kongos
# ✅ MATCH: cleanbandit == cleanbandit
# ✅ MATCH: djsnake == djsnake
# ✅ MATCH: juicyj == juicyj
# ✅ MATCH: cashcash == cashcash
# ✅ MATCH: naughtyboy == naughtyboy
# ✅ MATCH: beckyg == beckyg
# ✅ MATCH: hozier == hozier
# ✅ MATCH: tiesto == tiesto
# ✅ MATCH: ingridmichaelson == ingridmichaelson
# ✅ MATCH: kiesza == kiesza
# ✅ MATCH: kidink == kidink
# ✅ MATCH: alesso == alesso
# ✅ MATCH: fergie == fergie
# ✅ MATCH: ajr == ajr
# ✅ MATCH: jessglynne == jessglynne
# ✅ MATCH: tinashe == tinashe
# ✅ MATCH: yg == yg
# ✅ MATCH: marylambert == marylambert
# ✅ MATCH: beberexha == beberexha
# ✅ MATCH: twentyonepilots == twentyonepilots
# ✅ MATCH: alessiacara == alessiacara
# ✅ MATCH: daya == daya
# ✅ MATCH: dnce == dnce
# ✅ MATCH: shawnmendes == shawnmendes
# ✅ MATCH: lukasgraham == lukasgraham
# ✅ MATCH: zayn == zayn
# ✅ MATCH: charlieputh == charlieputh
# ✅ MATCH: g-eazy == g-eazy
# ✅ MATCH: zaralarsson == zaralarsson
# ✅ MATCH: xambassadors == xambassadors
# ✅ MATCH: kiiara == kiiara
# ✅ MATCH: majorlazer == majorlazer
# ✅ MATCH: jamesbay == jamesbay
# ✅ MATCH: halsey == halsey
# ✅ MATCH: flume == flume
# ✅ MATCH: troyesivan == troyesivan
# ✅ MATCH: ruthb. == ruthb.
# ✅ MATCH: gnash == gnash
# ✅ MATCH: torylanez == torylanez
# ✅ MATCH: jonbellion == jonbellion
# ✅ MATCH: kentjones == kentjones
# ✅ MATCH: niallhoran == niallhoran
# ✅ MATCH: gwenstefani == gwenstefani
# ✅ MATCH: camilacabello == camilacabello
# ✅ MATCH: rachelplatten == rachelplatten
# ✅ MATCH: desiigner == desiigner
# ✅ MATCH: mnek == mnek
# ✅ MATCH: jordanfisher == jordanfisher
# ✅ MATCH: shawnhook == shawnhook
# ✅ MATCH: robinschulz == robinschulz
# ✅ MATCH: oliviao'brien == oliviao'brien
# ✅ MATCH: kai == kai
# ✅ MATCH: grace == grace
# ✅ MATCH: torikelly == torikelly
# ✅ MATCH: frenship == frenship
# ✅ MATCH: rozes == rozes
# ✅ MATCH: dualipa == dualipa
# ✅ MATCH: kyla == kyla
# ✅ MATCH: wizkid == wizkid
# ✅ MATCH: travisscott == travisscott
# ✅ MATCH: benrector == benrector
# ✅ MATCH: postmalone == postmalone
# ✅ MATCH: timeflies == timeflies
# ✅ MATCH: r.city == r.city
# ✅ MATCH: bipolarsunshine == bipolarsunshine
# ✅ MATCH: khalid == khalid
# ✅ MATCH: liampayne == liampayne
# ✅ MATCH: portugal.theman == portugal.theman
# ✅ MATCH: juliamichaels == juliamichaels
# ✅ MATCH: samhunt == samhunt
# ✅ MATCH: quavo == quavo
# ✅ MATCH: guccimane == guccimane
# ✅ MATCH: future == future
# ✅ MATCH: migos == migos
# ✅ MATCH: cheatcodes == cheatcodes
# ✅ MATCH: machinegunkelly == machinegunkelly
# ✅ MATCH: luisfonsi == luisfonsi
# ✅ MATCH: sabrinacarpenter == sabrinacarpenter
# ✅ MATCH: kygo == kygo
# ✅ MATCH: childishgambino == childishgambino
# ✅ MATCH: marianhill == marianhill
# ✅ MATCH: frenchmontana == frenchmontana
# ✅ MATCH: harrystyles == harrystyles
# ✅ MATCH: logic == logic
# ✅ MATCH: cardib == cardib
# ✅ MATCH: max == max
# ✅ MATCH: noahcyrus == noahcyrus
# ✅ MATCH: macklemore == macklemore
# ✅ MATCH: starley == starley
# ✅ MATCH: haileesteinfeld == haileesteinfeld
# ✅ MATCH: marshmello == marshmello
# ✅ MATCH: anne-marie == anne-marie
# ✅ MATCH: partynextdoor == partynextdoor
# ✅ MATCH: keithurban == keithurban
# ✅ MATCH: liluzivert == liluzivert
# ✅ MATCH: nf == nf
# ✅ MATCH: blackbear == blackbear
# ✅ MATCH: jbalvin == jbalvin
# ✅ MATCH: willywilliam == willywilliam
# ✅ MATCH: lauv == lauv
# ✅ MATCH: sza == sza
# ✅ MATCH: daddyyankee == daddyyankee
# ✅ MATCH: louistomlinson == louistomlinson
# ✅ MATCH: lilyachty == lilyachty
# ✅ MATCH: kyle == kyle
# ✅ MATCH: lukecombs == lukecombs
# ✅ MATCH: swaelee == swaelee
# ✅ MATCH: heyviolet == heyviolet
# ✅ MATCH: gnash == gnash
# ✅ MATCH: raesremmurd == raesremmurd
# ✅ MATCH: juicewrld == juicewrld
# ✅ MATCH: panic!atthedisco == panic!atthedisco
# ✅ MATCH: lovelytheband == lovelytheband
# ✅ MATCH: brycevine == brycevine
# ✅ MATCH: normani == normani
# ✅ MATCH: bts == bts
# ✅ MATCH: bazzi == bazzi
# ✅ MATCH: dan+shay == dan+shay
# ✅ MATCH: whydon'twe == whydon'twe
# ✅ MATCH: madisonbeer == madisonbeer
# ✅ MATCH: backstreetboys == backstreetboys
# ✅ MATCH: bennyblanco == bennyblanco
# ✅ MATCH: marenmorris == marenmorris
# ✅ MATCH: grey == grey
# ✅ MATCH: lsd == lsd
# ✅ MATCH: ellamai == ellamai
# ✅ MATCH: badbunny == badbunny
# ✅ MATCH: bigboi == bigboi
# ✅ MATCH: alicemerton == alicemerton
# ✅ MATCH: diplo == diplo
# ✅ MATCH: deanlewis == deanlewis
# ✅ MATCH: inreallife == inreallife
# ✅ MATCH: markronson == markronson
# ✅ MATCH: silkcity == silkcity
# ✅ MATCH: dennislloyd == dennislloyd
# ✅ MATCH: walkthemoon == walkthemoon
# ✅ MATCH: kehlani == kehlani
# ✅ MATCH: weezer == weezer
# ✅ MATCH: loudluxury == loudluxury
# ✅ MATCH: jack&jack == jack&jack
# ✅ MATCH: thirtysecondstomars == thirtysecondstomars
# ✅ MATCH: jonasbrothers == jonasbrothers
# ✅ MATCH: lizzo == lizzo
# ✅ MATCH: billieeilish == billieeilish
# ✅ MATCH: lilnasx == lilnasx
# ✅ MATCH: avamax == avamax
# ✅ MATCH: lewiscapaldi == lewiscapaldi
# ✅ MATCH: shaed == shaed
# ✅ MATCH: laurendaigle == laurendaigle
# ✅ MATCH: ajmitchell == ajmitchell
# ✅ MATCH: fletcher == fletcher
# ✅ MATCH: kanebrown == kanebrown
# ✅ MATCH: mabel == mabel
# ✅ MATCH: tonesandi == tonesandi
# ✅ MATCH: allybrooke == allybrooke
# ✅ MATCH: saweetie == saweetie
# ✅ MATCH: liltecca == liltecca
# ✅ MATCH: blancobrown == blancobrown
# ✅ MATCH: youngthug == youngthug
# ✅ MATCH: kodakblack == kodakblack
# ✅ MATCH: offset == offset
# ✅ MATCH: socialhouse == socialhouse
# ✅ MATCH: georgeezra == georgeezra
# ✅ MATCH: illenium == illenium
# ✅ MATCH: arizonazervas == arizonazervas
# ✅ MATCH: draxproject == draxproject
# ✅ MATCH: monstax == monstax
# ✅ MATCH: dojacat == dojacat
# ✅ MATCH: trevordaniel == trevordaniel
# ✅ MATCH: gabbybarrett == gabbybarrett
# ✅ MATCH: dababy == dababy
# ✅ MATCH: blackbear == blackbear
# ✅ MATCH: roddyricch == roddyricch
# ✅ MATCH: megantheestallion == megantheestallion
# ✅ MATCH: saintjhn == saintjhn
# ✅ MATCH: regard == regard
# ✅ MATCH: surfaces == surfaces
# ✅ MATCH: morganwallen == morganwallen
# ✅ MATCH: surfmesa == surfmesa
# ✅ MATCH: jpsaxe == jpsaxe
# ✅ MATCH: benee == benee
# ✅ MATCH: jawsh685 == jawsh685
# ✅ MATCH: conangray == conangray
# ✅ MATCH: powfu == powfu
# ✅ MATCH: lilmosey == lilmosey
# ✅ MATCH: zoewees == zoewees
# ✅ MATCH: ashe == ashe
# ✅ MATCH: avenuebeat == avenuebeat
# ✅ MATCH: jackharlow == jackharlow
# ✅ MATCH: public == public
# ✅ MATCH: jacksonwang == jacksonwang
# ✅ MATCH: brockhampton == brockhampton
# ✅ MATCH: ianndior == ianndior
# ✅ MATCH: emilee == emilee
# ✅ MATCH: tatemcrae == tatemcrae
# ✅ MATCH: gusdapperton == gusdapperton
# ✅ MATCH: chancetherapper == chancetherapper
# ✅ MATCH: chelseacutler == chelseacutler
# ✅ MATCH: lildurk == lildurk
# ✅ MATCH: cyn == cyn
# ✅ MATCH: oliviarodrigo == oliviarodrigo
# ✅ MATCH: giveon == giveon
# ✅ MATCH: maskedwolf == maskedwolf
# ✅ MATCH: duncanlaurence == duncanlaurence
# ✅ MATCH: popsmoke == popsmoke
# ✅ MATCH: glassanimals == glassanimals
# ✅ MATCH: kaliuchis == kaliuchis
# ✅ MATCH: rittmomney == rittmomney
# ✅ MATCH: taiverdes == taiverdes
# ✅ MATCH: walkerhayes == walkerhayes
# ✅ MATCH: nessabarrett == nessabarrett
# ✅ MATCH: polog == polog
# ✅ MATCH: eltonjohn == eltonjohn
# ✅ MATCH: anitta == anitta
# ✅ MATCH: wizkid == wizkid
# ✅ MATCH: alltimelow == alltimelow
# ✅ MATCH: farruko == farruko
# ✅ MATCH: bbno$ == bbno$
# ✅ MATCH: bennyblanco == bennyblanco
# ✅ MATCH: lilbaby == lilbaby
# ✅ MATCH: sigala == sigala
# ✅ MATCH: loona == loona
# ✅ MATCH: liltjay == liltjay
# ✅ MATCH: ianndior == ianndior
# ✅ MATCH: internetmoney == internetmoney
# ✅ MATCH: danielcaesar == danielcaesar
# ✅ MATCH: jhaycortez == jhaycortez
# ✅ MATCH: cj == cj
# ✅ MATCH: stevelacy == stevelacy
# ✅ MATCH: laurenspencer-smith == laurenspencer-smith
# ✅ MATCH: gayle == gayle
# ✅ MATCH: dovecameron == dovecameron
# ✅ MATCH: embeihold == embeihold
# ✅ MATCH: joji == joji
# ✅ MATCH: katebush == katebush
# ✅ MATCH: nickyyoure == nickyyoure
# ✅ MATCH: stephensanchez == stephensanchez
# ✅ MATCH: jax == jax
# ✅ MATCH: jvke == jvke
# ✅ MATCH: yunggravy == yunggravy
# ✅ MATCH: rosalinn == rosalinn
# ✅ MATCH: jnrchoi == jnrchoi
# ✅ MATCH: leahkate == leahkate
# ✅ MATCH: jid == jid
# ✅ MATCH: jungkook == jungkook
# ✅ MATCH: encantocast == encantocast
# ✅ MATCH: kimpetras == kimpetras
# ✅ MATCH: armaniwhite == armaniwhite
# ✅ MATCH: bensonboone == bensonboone
# ✅ MATCH: emmymeli == emmymeli
# ✅ MATCH: charlottesands == charlottesands
# ✅ MATCH: blxst == blxst
# ✅ MATCH: acraze == acraze
# ✅ MATCH: olivertree == olivertree
# ✅ MATCH: ckay == ckay
# ✅ MATCH: fireboydml == fireboydml
# ✅ MATCH: munilong == munilong
# ✅ MATCH: lawrence == lawrence
# ✅ MATCH: coileray == coileray
# ✅ MATCH: jellyroll == jellyroll
# ✅ MATCH: davidkushner == davidkushner
# ✅ MATCH: paulrussell == paulrussell
# ✅ MATCH: fiftyfifty == fiftyfifty
# ✅ MATCH: rema == rema
# ✅ MATCH: pinkpantheress == pinkpantheress
# ✅ MATCH: toosii == toosii
# ✅ MATCH: jvke == jvke
# ✅ MATCH: icespice == icespice
# ✅ MATCH: bakar == bakar
# ✅ MATCH: (g)i-dle == (g)i-dle
# ✅ MATCH: metroboomin == metroboomin
# ✅ MATCH: raye == raye
# ✅ MATCH: dominicfike == dominicfike
# ✅ MATCH: tyla == tyla
# ✅ MATCH: noahkahan == noahkahan
# ✅ MATCH: kenyagrace == kenyagrace
# ✅ MATCH: melaniemartinez == melaniemartinez
# ✅ MATCH: xg == xg
# ✅ MATCH: lizzymcalpine == lizzymcalpine
# ✅ MATCH: mimiwebb == mimiwebb
# ✅ MATCH: kaliii == kaliii
# ✅ MATCH: jain == jain
# ✅ MATCH: zachbryan == zachbryan
# ✅ MATCH: kylieminogue == kylieminogue
# ✅ MATCH: summerwalker == summerwalker
# ✅ MATCH: tylayaweh == tylayaweh
# ✅ MATCH: playboicarti == playboicarti
# ✅ MATCH: 'nsync == 'nsync
# ✅ MATCH: gracieabrams == gracieabrams
# ✅ MATCH: teddyswims == teddyswims
# ✅ MATCH: fettywap == fettywap
# ✅ MATCH: omi == omi
# ✅ MATCH: elleking == elleking
# ✅ MATCH: natalielarose == natalielarose
# ✅ MATCH: silento == silento
# ✅ MATCH: ellahenderson == ellahenderson
# ✅ MATCH: vancejoy == vancejoy
# ✅ MATCH: shaggy == shaggy
# ✅ MATCH: sagethegemini == sagethegemini
# ✅ MATCH: alunageorge == alunageorge
# ✅ MATCH: asaprocky == asaprocky
# ✅ MATCH: skrillex == skrillex
# ✅ MATCH: paulmccartney == paulmccartney
# ✅ MATCH: disciples == disciples
# ✅ MATCH: omarion == omarion
# ✅ MATCH: sheppard == sheppard
# ✅ MATCH: lunchmoneylewis == lunchmoneylewis
# ✅ MATCH: rudimental == rudimental
# ✅ MATCH: conradsewell == conradsewell
# ✅ MATCH: jidenna == jidenna
# ✅ MATCH: thomasrhett == thomasrhett

# %%
filtered_df
# Out:
#                artist                    link
# 0               Kesha             k/keha.html
# 1             Rihanna          r/rihanna.html
# 2           Lady Gaga         l/ladygaga.html
# 3        Jason Derulo      j/jasonderulo.html
# 4          Katy Perry        k/katyperry.html
# ..                ...                     ...
# 536  LunchMoney Lewis  l/lunchmoneylewis.html
# 537        Rudimental       r/rudimental.html
# 538     Conrad Sewell     c/conradsewell.html
# 539           Jidenna          j/jidenna.html
# 540      Thomas Rhett      t/thomasrhett.html
#
# [535 rows x 2 columns]

# %%
filtered_df.to_csv("filtered_artist_links.csv", index=False)

# %% [markdown]
# ## 🎵 Fetch All Songs and Song Links for Each Artist
#
# This function visits each artist's AZLyrics profile page and collects:
#
# - Song titles
# - Corresponding song URLs
# - The album/single/EP name the song belongs to
#
# It returns a structured dataset with this information. Instrumentals and non-song sections are skipped.

# %%
d1 = pd.read_csv("fillter_artist_name_and_links.csv")
d1
# Out:
#      Unnamed: 0          artist                                      links
# 0             0           Kesha                                k/keha.html
# 1             1         Rihanna                             r/rihanna.html
# 2             2       Lady Gaga                            l/ladygaga.html
# 3             3    Jason Derulo                         j/jasonderulo.html
# 4             4      Katy Perry                           k/katyperry.html
# ..          ...             ...                                        ...
# 566         567   Jeremy Zucker                        j/jeremyzucker.html
# 567         568  Sandro Cavazza                       s/sandrocavazza.html
# 568         569     Jake Miller                          j/jakemiller.html
# 569         570        347aidan  https://www.azlyrics.com/19/347aidan.html
# 570         571          Haiden     https://www.azlyrics.com/h/haiden.html
#
# [571 rows x 3 columns]

# %%
dict = {'artist':[],
       'songs':[],
       'songs_links':[],
       'song_year':[]
      }

newdata = pd.DataFrame(dict)

# %%
def song_clean(name):
    a = name.find("(")
    if a == -1:
        song1 = name
    else:
        song1 = name[a:].strip()

    return song1
def fetch_songs(data,ept_data,loop):
    not_fetch_artist = []
    try:          # len(data["artist"])
        for i in range(loop,len(data["artist"]):
            print("loop : ",i)
            val = data["links"][i] 
            a_name = data["artist"][i]
            print("Artist name",a_name)
           # r = random.randint(8,15)
            time.sleep(5)
            #print("time",r)
            urls = f"https://www.azlyrics.com/{val}"
            print(urls)
            try:
                reqs = requests.get(urls)
            except:
                print("change proxy")
                break
            if (reqs.status_code != 200):
                print(" connection error ")
                break
            else:
                soup = BeautifulSoup(reqs.content,"html.parser")
                find = soup.find_all("div",{"class": "listalbum-item"})
                if(find == ""):
                    break
                #space = [title.text for title in find]
                #re_name = list(map(lambda x: x.replace('\n', ""), space))
                try:
                    all_name = [title.text for title in soup.find("div",id="listAlbum")]

                except:
                    all_name = [title.text for title in find]
                    if (all_name == []):
                        break
                #all_name = [title.text for title in soup.find("div",id="listAlbum")]
                #songs  links fetching  
                songs_link=[]
                a_tag = []
                for i in range(len(find)):
                    a_tag.append(find[i].find("a"))
                new_a_tag = []
                for i in a_tag:
                    if i != None:
                        new_a_tag.append(i) 
                for link in new_a_tag:
                    links = link.get('href')
                    songs_link.append(links)
                # fetching songs name 
                xx = []
                for i in all_name:
                    xx.append(i.replace("\n",""))
                while '' in xx:
                    xx.remove('')
                name =  xx[:-1]
                for k in range(4):
                    for m in name:
                        if("Instrumental" in m or "(Instrumental)" in m):
                            name.remove(m)
                        for jj in name:
                            if("Instrumental" in jj or "(Instrumental)" in jj):
                                name.remove(jj)
                new_name = []
                year = []
                a = "Nan"
                for i in name:
                    if "album:" in i or "single:" in i or "EP:" in i or "soundtrack:" in i or "demo:" in i or "mixtape" in i or "split EP" in i:
                        a = i
                        print(a)
                        name.remove(i)
                        #year.append(song_clean(a))
                    elif "other songs:" in i:
                        a = "Nan"
                        print(i)
                        name.remove(i)
                        #year.append(song_clean(a))
                    elif "Instrumental" in i:
                        print(i)
                        name.remove(i)
                        #year.append(song_clean(a))
                    year.append(song_clean(a))
                        #new_name.append(i)

                loop = i
                if len(name) == len(songs_link):
                    for j in range(len(name)):
                        ept_data.loc[len(ept_data.index)] = [a_name, name[j],songs_link[j],year[j]]

                else:
                    print(a_name," Something wrong with this artist we remove from dataset ")
                    not_fetch_artist = []
                    an = ept_data[ept_data['artist'] == a_name].index
                    ept_data.drop(index=an,inplace=True)
                    not_fetch_artist.append(a_name)
        return ept_data , not_fetch_artist,1,i
    except TypeError:
        print("something wrong in code")

# %% [markdown]
# ## Function Purpose Recap
#
# The original fetch_songs() function was written to:
#
# Fetch all songs from each artist’s page on AZLyrics
#
# Save the following info per song:
#
# Artist name
#
# Song name
#
# Song link
#
# song year
#
# Allow resuming from a specific index (e.g. after a crash or block)
#
# Avoid fetching duplicate data if partially completed

# %%
# Example: We fetch data for only one artist here to demonstrate 
# how the function works and verify it returns song names, links, 
# and album info correctly.
fetch_songs(d1,newdata,1)
# Out:
# loop :  1
# Artist name Rihanna
# https://www.azlyrics.com/r/rihanna.html
# album: "Music Of The Sun" (2005)
# album: "A Girl Like Me" (2006)
# album: "Good Girl Gone Bad" (2007)
# album: "Rated R" (2009)
# album: "Loud" (2010)
# album: "Talk That Talk" (2011)
# album: "Unapologetic" (2012)
# soundtrack: "Home" (2015)
# album: "Anti" (2016)
# other songs:
# (      artist                           songs  \
#  0    Rihanna                   Pon De Replay
#  1    Rihanna                 Here I Go Again
#  2    Rihanna    If It's Lovin' That You Want
#  3    Rihanna  You Don't Love Me (No, No, No)
#  4    Rihanna                 That La, La, La
#  ..       ...                             ...
#  163  Rihanna                   We Found Love
#  164  Rihanna                Whipping My Hair
#  165  Rihanna                Who's That Chick
#  166  Rihanna                   Winning Women
#  167  Rihanna                     World Peace
#
#                                        songs_links song_year
#  0                /lyrics/rihanna/pondereplay.html    (2005)
#  1               /lyrics/rihanna/hereigoagain.html    (2005)
#  2      /lyrics/rihanna/ifitslovinthatyouwant.html    (2005)
#  3        /lyrics/rihanna/youdontlovemenonono.html    (2005)
#  4                 /lyrics/rihanna/thatlalala.html    (2005)
#  ..                                            ...       ...
#  163  /lyrics/rihanna/wefoundlove-music-video.html       Nan
#  164           /lyrics/rihanna/whippingmyhair.html       Nan
#  165            /lyrics/rihanna/whosthatchick.html       Nan
#  166             /lyrics/rihanna/winningwomen.html       Nan
#  167               /lyrics/rihanna/worldpeace.html       Nan
#
#  [168 rows x 4 columns],
#  [],
#  1,
#  'World Peace')

# %%
# See the new data after fetch all the songs links and years
newdata.head()
# Out:
#     artist                           songs  \
# 0  Rihanna                   Pon De Replay
# 1  Rihanna                 Here I Go Again
# 2  Rihanna    If It's Lovin' That You Want
# 3  Rihanna  You Don't Love Me (No, No, No)
# 4  Rihanna                 That La, La, La
#
#                                   songs_links song_year
# 0            /lyrics/rihanna/pondereplay.html    (2005)
# 1           /lyrics/rihanna/hereigoagain.html    (2005)
# 2  /lyrics/rihanna/ifitslovinthatyouwant.html    (2005)
# 3    /lyrics/rihanna/youdontlovemenonono.html    (2005)
# 4             /lyrics/rihanna/thatlalala.html    (2005)

# %%
# Final save
newdata.to_csv("song_links_&_name.csv")

# %% [markdown]
# ## 🎶  Fetch Full Song Lyrics Using Collected Song Links
#
# Now that we've successfully scraped and stored:
#
# - Artist names
# - Song titles
# - Song years
# - Song page links (from AZLyrics)
#
# It's time to **move forward and fetch the full lyrics** for each song.
#
# We'll load the saved dataset `song_links_&_name.csv` and use the `song_link` column to visit each song's page and extract its lyrics.
#
# ```python

# %%
# Load the saved dataset containing song names and links
data1 = pd.read_csv("data/song_links_&_name.csv")

# Drop the unnecessary 'Unnamed: 0' index column (if it exists)
df = data1.drop(columns=["Unnamed: 0"], axis=1)

# Display the dataset to verify structure
df
# Out:
#          artist                 songs  \
# 0         Kesha              Bastards
# 1         Kesha          Let 'Em Talk
# 2         Kesha                 Woman
# 3         Kesha                  Hymn
# 4         Kesha               Praying
# ...         ...                   ...
# 35846  347aidan   The Weekend (Remix)
# 35847  347aidan    Till The Sun Comes
# 35848  347aidan               TROUBLE
# 35849  347aidan             Up & Down
# 35850  347aidan  WHEN THE DEVIL CRIES
#
#                                              songs_links song_year
# 0                             /lyrics/keha/bastards.html      2017
# 1                            /lyrics/keha/letemtalk.html      2017
# 2                                /lyrics/keha/woman.html      2017
# 3                                 /lyrics/keha/hymn.html      2017
# 4                              /lyrics/keha/praying.html      2017
# ...                                                  ...       ...
# 35846  https://www.azlyrics.com/lyrics/88rising/thewe...       Nan
# 35847              /lyrics/347aidan/tillthesuncomes.html       Nan
# 35848                      /lyrics/347aidan/trouble.html       Nan
# 35849  https://www.azlyrics.com/lyrics/chainsmokers/u...       Nan
# 35850            /lyrics/347aidan/whenthedevilcries.html       Nan
#
# [35851 rows x 4 columns]

# %%
import lyricsgenius
# 📘 Utility to separate mixed case words like "LoveYouMore" → "Love You More"
def split_mixed_text(text):
    words = re.split(r'(\s+|(?<=[a-z])(?=[A-Z])|-|(?<=[A-Z])(?=[A-Z][a-z])|(?<=[a-zA-Z])(?=\d))', text)
    words = [word for word in words if word.strip()]
    words = [re.sub(r'[^\w\s]', '', word) for word in words]
    return " ".join(words)

# 📘 Clean extra details from song title, like "Song Name (Acoustic Version)" → "Song Name"
def song_clean(name):
    a = name.find("(")
    if a == -1:
        song1 = name
    else:
        song1 = name[:a].strip()
    return song1

# 📘 Remove common structural text from lyrics like "Chorus", "Verse 1", brackets, etc.
def clean(result_string):
    re = result_string.replace('Verse 1', "")
    re1 = re.replace("Pre-Chorus","")
    re2 = re1.replace("Chorus","")
    re3 = re2.replace("Verse 2","")
    re4 = re3.replace("Outro","")
    re5 = re4.replace("[]","")
    re6 = re5.replace(",","")
    re7 = re6.replace("Intro","")
    re8 = re7.replace("'","")
    re9 = re8.replace("[","")
    r10 = re9.replace("]"," ")
    r11 = r10.replace("("," ")
    r12 = r11.replace(")"," ").replace("84Embed","").replace("8Embed","").replace("Embed","")
    r13 = r12.replace("?","").replace("Contributors","")
    r14 = r13.replace("\n"," ").replace("\r","")
    r15 = r14.replace(".","").replace("Bridge","")
    r16 = r15.replace("Verse 3","").replace("\u2005","")
    return r16

# 📘 Fallback method: If Genius direct URL fails, search the song on Genius using Google-style search
def genius_api(df,loop,data):
    genius = lyricsgenius.Genius("K-B4mzgcY2KxoIqd3y6cQfKUFd35h7ToXCneICM8uItRZZPLDRCtEkEeE2po18hL")
    for i in range(loop,1):
        artist_name = df["artist"][i]
        song_name = df["songs"][i]
        artist = genius.search_artist(artist_name,max_songs=1, sort="title")
        lyrics = artist.song(song_name)
        #print(clean(lyrics.lyrics)[len(song_name+"Lyrics"):])
        print(i)
        b.append(i)
        try:
            cln = clean(lyrics.lyrics)[len(song_name+"Lyrics"):]

            data.loc[len(data.index)] = [artist_name, song_name,cln]
        except:
            return i+1
    return i
            #data.loc[len(data.index)] = [artist_name, song_name,clean(lyrics)]


# 📘 Fetch lyrics from AZLyrics (preferred) using the partial song link
def azlayrics_fetch(df,loop,data):
    for i in range(loop,len(df["artist"])):
        print(i)
        link = df["songs_links"][i]
        artist = df["artist"][i]
        song = df["songs"][i]
        df["songs"][i]
        if "https" in link or "http" in link:
            print(link)
            try:
                reqs = requests.get(link,timeout=3)
            except:
                print("connection error")
                break
            so = BeautifulSoup(reqs.content,"html.parser")
            fi = so.findAll("div")[24:25]
            spac = [title.text for title in fi]
            ro = list(map(lambda x: x.replace('\u2005', ""), spac))    
            result_string = " ".join(ro)
            lay = clean(result_string)[2:].lower()
            data.loc[len(data.index)] = [artist, song,lay]

        else:
            url = f"https://www.azlyrics.com{link}"
            print(url)
            try:
                reqs = requests.get(url)
            except:
                print("connection error")
                break
            so = BeautifulSoup(reqs.content,"html.parser")
            fi = so.findAll("div")[24:25]
            spac = [title.text for title in fi]
            ro = list(map(lambda x: x.replace('\u2005', ""), spac))    
            result_string = " ".join(ro)
            lay = clean(result_string)[2:].lower()
            if lay != "":
                data.loc[len(data.index)] = [artist, song,lay]
            else:
                break
    return i

# %% [markdown]
# ## What This Setup Allows You To Do:
# Primary source: Fetch lyrics from AZLyrics (most accurate + direct).
#
# Backup option: If blocked or not available, use Genius (via URL + fallback search).
#
# Cleanup: Lyrics are stripped of metadata like "Verse 1", "Bridge", etc., for clean analysis.
#
# Flexibility: Supports any artist or song using artist + song_title.

# %%
#creating new dataframe for store new data with lyrics
dict = {'artist':[],
        'songs':[],
        'songs_lyrics':[]
       }

data = pd.DataFrame(dict)
data
# Out:
# Empty DataFrame
# Columns: [artist, songs, songs_lyrics]
# Index: []

# %% [markdown]
# ## 🎤 Using Genius API to Fetch Lyrics (Backup to AZLyrics)
#
# If AZLyrics blocks our IP address or stops responding, we can use the official **Genius API** as a backup to fetch song lyrics.
#
# The function `genius_api()` uses the `lyricsgenius` Python library to:
# - Authenticate using a Genius API key
# - Search for the artist and their song
# - Fetch and clean the lyrics
# - Store results in a DataFrame
#
# ### 🔑 Prerequisite:
# You need a Genius API token. In this example, it's already defined in the function:
# ```python
# genius = lyricsgenius.Genius("YOUR_GENIUS_API_KEY")

# %%
#demo how these function work
azlayrics_fetch(df,0,data)
# Out:
# 0
# https://www.azlyrics.com/lyrics/keha/bastards.html
# 1
# https://www.azlyrics.com/lyrics/keha/letemtalk.html
# 1

# %%
data
# Out:
#   artist         songs                                       songs_lyrics
# 0  Kesha      Bastards  one two three four one  i got too many people ...
# 1  Kesha  Let 'Em Talk  you you got your own opinions but baby i dont ...

# %%
row_num=[]

# %%
try:
    azlayrics_fetch(df,0,data)
except:
    az = genius_api(df,0,data)
    #incase of loop stop we can pass raw_num to continue where the loop stop
    row_num.append(az)

# %%
#after collect all songs lyrics now our data look like this 
data
# Out:
#          artist                 songs  \
# 0         Kesha              Bastards
# 1         Kesha          Let 'Em Talk
# 2         Kesha                 Woman
# 3         Kesha                  Hymn
# 4         Kesha               Praying
# ...         ...                   ...
# 36477  347aidan  WHEN THE DEVIL CRIES
# 36478  347aidan  WHEN THE DEVIL CRIES
# 36479  347aidan  WHEN THE DEVIL CRIES
# 36480  347aidan  WHEN THE DEVIL CRIES
# 36481  347aidan  WHEN THE DEVIL CRIES
#
#                                             songs_lyrics
# 0      one two three four one  i got too many people ...
# 1      you you got your own opinions but baby i dont ...
# 2      lets be serious come on this is a real this is...
# 3      even the stars and the moon dont shine quite l...
# 4      music-video spoken intro:  "am i dead or is th...
# ...                                                  ...
# 36477  ics  Yeah ayy No no no no no no no yeah yeah W...
# 36478  ics  Yeah ayy No no no no no no no yeah yeah W...
# 36479  ics  Yeah ayy No no no no no no no yeah yeah W...
# 36480  ics  Yeah ayy No no no no no no no yeah yeah W...
# 36481  ics  Yeah ayy No no no no no no no yeah yeah W...
#
# [36482 rows x 3 columns]

# %%
# now drop the duplicates row
data = data.drop_duplicates(subset=["songs_lyrics"],keep='first')
data
# Out:
#          artist                 songs  \
# 0         Kesha              Bastards
# 1         Kesha          Let 'Em Talk
# 2         Kesha                 Woman
# 3         Kesha                  Hymn
# 4         Kesha               Praying
# ...         ...                   ...
# 36277  347aidan                SUNDAY
# 36278  347aidan   The Weekend (Remix)
# 36279  347aidan    Till The Sun Comes
# 36280  347aidan               TROUBLE
# 36282  347aidan  WHEN THE DEVIL CRIES
#
#                                             songs_lyrics
# 0      one two three four one  i got too many people ...
# 1      you you got your own opinions but baby i dont ...
# 2      lets be serious come on this is a real this is...
# 3      even the stars and the moon dont shine quite l...
# 4      music-video spoken intro:  "am i dead or is th...
# ...                                                  ...
# 36277  ics   Yeah its like this    I woke up this mor...
# 36278  ics: BIBI  Barbie wanna party like all night A...
# 36279  rics  Its hard to uh Get a grasp of whats goin...
# 36280  ics  Now I knew that you were trouble And now ...
# 36282  ics  Yeah ayy No no no no no no no yeah yeah W...
#
# [33626 rows x 3 columns]

# %%
#ready to save data
data.to_csv("data/top_and_famous_artist_songs_with_lyrics.csv")

# %%
data.songs_lyrics[3434]
# Out:
# 'Lyrics Sure you can have the towels You can take my money Drag my name round town I dont mind I changed it anyway They say the worst parts of someone Come out to play when shit goes wrong So shit must hit the fan with you all day hey   As you run your mouth puff your chest Play cowboy in the wild wild west I dont mind you know best Keep on ridin til you cant see us I learned the hard way about love Sometimes it just isnt enough   But sure you can have the towels  Theyre all yours  Tell em all Im crazy  Loco  What a nice cliché blamin me I guess Some things never change  Bitch  Finding out what went down As soon as I wasnt around Broke my heart but hey Ill be okay hey You might also like As you run your mouth puff your chest Play cowboy in the wild wild west I dont mind you know best Keep on ridin til you cant see us Did you know theres only one truth And in the end you have to live with what you do     Ride ride along   Far far away  Oh-oh oh oh oh  Ride ride along  Oh-oh  Far far away    So run your mouth puff your chest Play cowboy in the wild wild west I dont mind take whats left High road livin is what I do best So run your mouth puff your chest Play cowboy in the wild wild west I dont mind take whats left High road livin is what I do best    Ride ride along  What I do best  Far far away  I learned the hard way about me Red flag collector drownin in your troubled seas'

# %% [markdown]
# ## 🎶 Lyrics Dataset Project (2017–2024) — AZLyrics + Genius API
#
# This project involves collecting and curating a high-quality lyrics dataset using a combination of **web scraping** and **official API integration**. It is tailored specifically for **modern music analysis**, using **top and popular artists** from 2017 to 2024.
#
# ---
#
# ### 📥 Data Collection Highlights
#
# - ✅ Scraped artist pages and song lyrics from **AZLyrics**
# - 🔁 Used **Genius API** as a backup when AZLyrics failed or was blocked
# - 🎤 Focused on **top global artists** and **famous musicians**
# - ⏳ Included only **songs released from 2017 to 2024** to ensure relevance
# - 🧹 Cleaned out non-lyrical content (e.g., "Verse", "Chorus", "Outro")
#
# ---
#
# ### 📁 Dataset Structure
#
# | Column        | Description                            |
# |---------------|----------------------------------------|
# | `artist`      | Artist name                            |
# | `song_name`   | Title of the song                      |
# | `lyrics`      | Cleaned full lyrics                    |
#
# ---
#
# ### 🔬 Real-World Use Cases
#
# This dataset is ideal for various **data science, NLP, and machine learning tasks**, such as:
#
# - 🧠 **Sentiment Analysis**
#   Understand the emotions conveyed in songs or build models to detect mood.
#
# - 🎧 **Music Recommendation Systems**
#   Recommend songs to users based on lyrical similarity or themes.
#
# - 🗣️ **Topic Modeling & Theme Extraction**
#   Discover recurring themes like love, heartbreak, freedom, etc.
#
# - 🧬 **Stylometry & Artist Profiling**
#   Analyze linguistic style and word choices across different artists or genres.
#
# - 📈 **Trend Analysis Over Time**
#   Observe how lyrical content has evolved from 2017 to 2024.
#
# - 🤖 **Text Generation & Language Modeling**
#   Train models to generate lyrics in the style of particular artists.
#
# - 🔍 **Genre or Gender-Based Analysis**
#   Study differences in lyrics between genres (e.g., pop vs. hip-hop) or male vs. female artists.
#
# ---
#
# ### 📂 Dataset Access
#
# This dataset is uploaded and publicly available on **Kaggle**:
#
# 🔗 [**Download on Kaggle**](https://www.kaggle.com/datasets/uvaissaifi/top-artist-songs-with-lyrics-20172024/data)
#
# ---
#
# ### 🛠️ Tools & Libraries Used
#
# - `requests`, `BeautifulSoup` — Web scraping from AZLyrics & Genius
# - `lyricsgenius` — API access to Genius lyrics
# - `pandas`, `re`, `time`, `selenium` — Data parsing and cleaning
# - `CSV` export — For structured, portable data format
#
# ---
#
# ### ✅ Conclusion
#
# This modern, clean, and well-structured dataset is perfect for anyone working on **music intelligence**, **language processing**, or **AI-driven music apps**. It bridges the gap between raw music content and machine learning.
#
# Whether you're a **researcher, data scientist, or developer**, this dataset provides the right foundation to build innovative audio-lyrical models.
